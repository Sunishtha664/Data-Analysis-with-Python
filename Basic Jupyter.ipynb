# %%
9+6
# Out:
# 15

# %%
print(20)
# Out:
# 20

# %%
print("My name is Sunishtha")
# Out:
# My name is Sunishtha

# %%
x=5
print(x)
# Out:
# 5

# %%
Name = "Sunu"
print(Name)
# Out:
# Sunu

# %%
age = 18
if age >= 18:
    print("You are an adult")
else:
    print("you are minor")
# Out:
# You are an adult

# %%
score = 75
if score>=90:
    grade = 'A'
elif score>=80:
    grade = 'B'
elif score>=70:
    grade = 'C'
else:
    grade = 'D'
print("grade is",grade)
# Out:
# grade is C

# %%
count = 0
while count<5:
    print("Count is",count)
    count +=1
# Out:
# Count is 0
# Count is 1
# Count is 2
# Count is 3
# Count is 4

# %%
i=1
n=5
while i<=n:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruits=["apple","banana","cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
n=4
for i in range(0,n):
    print(i)
# Out:
# 0
# 1
# 2
# 3
